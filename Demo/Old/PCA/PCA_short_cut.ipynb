# %%
# https://plot.ly/python/v3/ipython-notebooks/principal-component-analysis/

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA as sklearnPCA
import matplotlib.pyplot as plt


table = pd.read_csv("data/heart_table.csv")
table
# Out:
#       age  sex  chestpain  restBP   chol  sugar  ecg  maxhr  angina  dep  \
# 0    70.0  1.0        4.0   130.0  322.0    0.0  2.0  109.0     0.0  2.4
# 1    67.0  0.0        3.0   115.0  564.0    0.0  2.0  160.0     0.0  1.6
# 2    57.0  1.0        2.0   124.0  261.0    0.0  0.0  141.0     0.0  0.3
# 3    64.0  1.0        4.0   128.0  263.0    0.0  0.0  105.0     1.0  0.2
# 4    74.0  0.0        2.0   120.0  269.0    0.0  2.0  121.0     1.0  0.2
# ..    ...  ...        ...     ...    ...    ...  ...    ...     ...  ...
# 265  52.0  1.0        3.0   172.0  199.0    1.0  0.0  162.0     0.0  0.5
# 266  44.0  1.0        2.0   120.0  263.0    0.0  0.0  173.0     0.0  0.0
# 267  56.0  0.0        2.0   140.0  294.0    0.0  2.0  153.0     0.0  1.3
# 268  57.0  1.0        4.0   140.0  192.0    0.0  0.0  148.0     0.0  0.4
# 269  67.0  1.0        4.0   160.0  286.0    0.0  2.0  108.0     1.0  1.5
#
#      exercise  fluor  thal  diagnosis
# 0         2.0    3.0   3.0          2
# ...

# %%
X_std = StandardScaler().fit_transform(table)

# %%
sklearn_pca = sklearnPCA(.80)
X_pca = sklearn_pca.fit_transform(X_std)

# %%
pc1 = X_pca[:,0]
pc2 = X_pca[:,1]
diag = X_std[:,-1]

plt.scatter(pc1, pc2,c=diag, cmap=plt.cm.Paired)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()
