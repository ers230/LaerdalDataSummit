# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the data

# %%
features_norm = pd.read_csv('Data/heart_features.csv')
features_norm = features_norm.drop(columns="ecg_1.0")
features_norm.describe()
# Out:
#                 age           sex        restBP          chol         sugar  \
# count  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02
# mean   3.371788e-16 -7.977158e-17  5.978757e-16 -1.944946e-16  4.646489e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.792090e+00 -1.447639e+00 -2.090766e+00 -2.392499e+00 -4.162558e-01
# 25%   -7.062560e-01 -1.447639e+00 -6.351301e-01 -7.092654e-01 -4.162558e-01
# 50%    6.220908e-02  6.882217e-01 -7.527007e-02 -9.014507e-02 -4.162558e-01
# 75%    7.208935e-01  6.882217e-01  4.845899e-01  5.870178e-01 -4.162558e-01
# max    2.477385e+00  6.882217e-01  3.843750e+00  6.081711e+00  2.393471e+00
#
#               maxhr        angina           dep      exercise         fluor  \
# count  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02
# mean   2.960595e-17  2.417819e-16  3.361509e-16 -1.225357e-16  1.151342e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.396302e+00 -6.999225e-01 -9.168625e-01 -9.524656e-01 -7.102161e-01
# 25%   -7.199336e-01 -6.999225e-01 -9.168625e-01 -9.524656e-01 -7.102161e-01
# 50%    1.649948e-01 -6.999225e-01 -2.183006e-01  6.751655e-01 -7.102161e-01
# 75%    7.045852e-01  1.423438e+00  4.802613e-01  6.751655e-01  3.492223e-01
# max    2.258606e+00  1.423438e+00  4.496992e+00  2.302797e+00  2.468099e+00
#
#        chestpain_1.0  chestpain_2.0  chestpain_3.0  chestpain_4.0  \
# count   2.700000e+02   2.700000e+02   2.700000e+02   2.700000e+02
# mean   -1.332268e-16   7.401487e-18  -1.307596e-16  -1.052656e-16
# std     1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
# min    -2.823184e-01  -4.284020e-01  -6.419351e-01  -9.547278e-01
# 25%    -2.823184e-01  -4.284020e-01  -6.419351e-01  -9.547278e-01
# 50%    -2.823184e-01  -4.284020e-01  -6.419351e-01  -9.547278e-01
# 75%    -2.823184e-01  -4.284020e-01   1.552020e+00   1.043540e+00
# max     3.528981e+00   2.325611e+00   1.552020e+00   1.043540e+00
#
#             ecg_0.0       ecg_2.0      thal_3.0      thal_6.0      thal_7.0
# count  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02  2.700000e+02
# mean   1.184238e-16  1.069104e-17 -1.916163e-16 -1.167790e-16 -1.891491e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.689972e-01 -1.013045e+00 -1.132857e+00 -2.334201e-01 -7.900542e-01
# 25%   -9.689972e-01 -1.013045e+00 -1.132857e+00 -2.334201e-01 -7.900542e-01
# 50%   -9.689972e-01  9.834670e-01  8.794547e-01 -2.334201e-01 -7.900542e-01
# 75%    1.028173e+00  9.834670e-01  8.794547e-01 -2.334201e-01  1.261048e+00
# max    1.028173e+00  9.834670e-01  8.794547e-01  4.268254e+00  1.261048e+00

# %% [markdown]
# ### Visualize the data

# %%
sns.heatmap(features_norm)
plt.show()

# %% [markdown]
# ### Order by Cluster

# %%
kmeans = KMeans(n_clusters=2, init='k-means++').fit(features_norm)
clusters = kmeans.predict(features_norm)
features_norm['kMeans'] = clusters
sns.heatmap(features_norm.sort_values(by=['kMeans']))
plt.show()

# %% [markdown]
# # Learn More:
# ### https://towardsdatascience.com/clustering-with-k-means-1e07a8bfb7ca
# ### https://www.youtube.com/watch?v=esmzYhuFnds
